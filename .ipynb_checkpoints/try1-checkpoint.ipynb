# %%
import pandas as pd

# %%
import sys
sys.path.append("../../../") # go to parent dir
from fastai.tabular import *

# %%
df = pd.read_csv('train.csv')

# %%
test = pd.read_csv('test.csv')

# %%
test
# Out:
#         Id         x1         x2        x3        x4        x5        x6  \
# 0     2000  25.416720  25.755544  4.830466  3.217945  4.226192  2.701034
# 1     2001  31.675273  35.623995  5.702935  4.459268  4.021896  3.511048
# 2     2002  36.029493  41.306224  6.407306  4.680895  3.824754  3.438547
# 3     2003  32.576287  23.072771  6.365671  3.388560  4.049858  3.792925
# 4     2004  29.196610  24.863397  3.801012  4.171005  4.865999  4.296043
# 5     2005  32.372161  28.882692  5.772703  5.198338  3.835582  3.497330
# 6     2006  34.721893  18.056551  5.010716  4.735449  4.099406  3.240893
# 7     2007  32.537394  25.174264  6.573874  4.979148  4.137794  4.214150
# 8     2008  22.867974  29.091751  6.844772  4.167746  2.158402  4.516612
# 9     2009  27.503399  30.352711  6.016668  5.066178  4.207576  3.326139
# 10    2010  20.930645  22.145193  6.759150  4.231905  4.208669  4.519367
# 11    2011  22.492345  21.661698  6.659538  5.080445  4.208005  3.240155
# ...

# %%
df = df.drop('Id', axis=1)

# %%
test = test.drop('Id', axis=1)

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# Total time: 00:07 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.247703</td>
#       <td>0.259093</td>
#       <td>0.930000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.250516</td>
#       <td>0.257029</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.254411</td>
#       <td>0.260307</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.250659</td>
#       <td>0.272092</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.246935</td>
#       <td>0.264819</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
# ...

# %%
valid_idx = range(len(df)-100, len(df))

# %%
dep_var = 'y'
cat_names = []
procs = [Normalize]

# %%
data = TabularDataBunch.from_df('./', df, dep_var, valid_idx=valid_idx, procs=procs, cat_names=cat_names, test_df = test)

# %%
print(data.train_ds.cont_names)
# Out:
# ['x6', 'x3', 'x10', 'x20', 'x9', 'x17', 'x12', 'x7', 'x16', 'x14', 'x5', 'x19', 'x2', 'x13', 'x11', 'x8', 'x1', 'x15', 'x18', 'x4']

# %%
learn = tabular_learner(data, layers=[200,100], emb_szs={}, metrics=accuracy)

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(14, 1e-3)
# Out:
# Total time: 00:11 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.110536</td>
#       <td>1.063037</td>
#       <td>0.460000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.001461</td>
#       <td>0.865108</td>
#       <td>0.640000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.889137</td>
#       <td>0.728684</td>
#       <td>0.670000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.782942</td>
#       <td>0.598580</td>
#       <td>0.760000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.695269</td>
#       <td>0.516167</td>
#       <td>0.770000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
# ...

# %%
learn.fit_one_cycle(3, 1e-3)
# Out:
# Total time: 00:02 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.329240</td>
#       <td>0.312955</td>
#       <td>0.900000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.337509</td>
#       <td>0.287308</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.316778</td>
#       <td>0.278714</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3, 1e-3)
# Out:
# Total time: 00:02 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.289256</td>
#       <td>0.278863</td>
#       <td>0.890000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.301838</td>
#       <td>0.285804</td>
#       <td>0.900000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.281768</td>
#       <td>0.259388</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('try1introml')

# %%
learn.fit_one_cycle(3, 1e-3)
# Out:
# Total time: 00:02 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.277901</td>
#       <td>0.281565</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.281469</td>
#       <td>0.281649</td>
#       <td>0.880000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.258523</td>
#       <td>0.289018</td>
#       <td>0.900000</td>
#       <td>00:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.load('try1introml')
# Out:
# Learner(data=TabularDataBunch;
#
# Train: LabelList (1900 items)
# x: TabularList
# ...

# %%
learn.fit_one_cycle(5, 1e-4)
# Out:
# Total time: 00:04 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.259211</td>
#       <td>0.264476</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.254917</td>
#       <td>0.273471</td>
#       <td>0.930000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.261280</td>
#       <td>0.262355</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.261809</td>
#       <td>0.265826</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.250931</td>
#       <td>0.252000</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
# ...

# %%
learn.save('try2introml')

# %%
learn.fit_one_cycle(5, 1e-5)
# Out:
# Total time: 00:04 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.234212</td>
#       <td>0.266931</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.245948</td>
#       <td>0.264380</td>
#       <td>0.900000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.245985</td>
#       <td>0.257066</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.244725</td>
#       <td>0.260357</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.247717</td>
#       <td>0.265849</td>
#       <td>0.900000</td>
#       <td>00:00</td>
#     </tr>
# ...

# %%
learn.load('try2introml')
# Out:
# Learner(data=TabularDataBunch;
#
# Train: LabelList (1900 items)
# x: TabularList
# ...

# %%
learn.fit_one_cycle(10, 1e-4)
# Out:
# Total time: 00:07 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.247703</td>
#       <td>0.259093</td>
#       <td>0.930000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.250516</td>
#       <td>0.257029</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.254411</td>
#       <td>0.260307</td>
#       <td>0.920000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.250659</td>
#       <td>0.272092</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.246935</td>
#       <td>0.264819</td>
#       <td>0.910000</td>
#       <td>00:00</td>
#     </tr>
#     <tr>
# ...

# %%
learn.export()
PATH = learn.path
learn = load_learner(PATH, test = TabularList.from_csv(csv_name='test.csv', path='./'))
# Out:
# ---------------------------------------------------------------
# TypeError                     Traceback (most recent call last)
# <ipython-input-27-9d90e41cfe1b> in <module>
#       1 learn.export()
#       2 PATH = learn.path
# ----> 3 learn = load_learner(PATH, test = TabularList.from_csv(csv_name='test.csv', path='./'))
#
# ~/fastai/fastai/fastai/data_block.py in from_csv(cls, path, csv_name, cols, delimiter, header, processor, **kwargs)
#     128         """Create an `ItemList` in `path` from the inputs in the `cols` of `path/csv_name`"""
#     129         df = pd.read_csv(Path(path)/csv_name, delimiter=delimiter, header=header)
# --> 130         return cls.from_df(df, path=path, cols=cols, processor=processor, **kwargs)
#     131
#     132     def _relative_item_path(self, i): return self.items[i].relative_to(self.path)
#
# ~/fastai/fastai/fastai/tabular/data.py in from_df(cls, df, cat_names, cont_names, procs, **kwargs)
# ...

# %%
learn.test = TabularList.from_df(df, path=PATH, cat_names=[], cont_names=df.columns)

# %%
df.columns
# Out:
# Index(['y', 'x1', 'x2', 'x3', 'x4', 'x5', 'x6', 'x7', 'x8', 'x9', 'x10', 'x11',
#        'x12', 'x13', 'x14', 'x15', 'x16', 'x17', 'x18', 'x19', 'x20'],
#       dtype='object')

# %%
learn.get_preds()
# Out:
# [tensor([[3.6728e-02, 5.6815e-02, 9.0646e-01],
#          [8.4252e-01, 1.3946e-01, 1.8024e-02],
#          [3.7988e-01, 4.4119e-01, 1.7892e-01],
#          [8.5287e-05, 6.5891e-04, 9.9926e-01],
#          [7.2275e-01, 3.3137e-02, 2.4412e-01],
#          [8.4513e-01, 1.1315e-01, 4.1727e-02],
#          [7.3201e-03, 3.5952e-03, 9.8908e-01],
#          [2.7708e-01, 6.6887e-01, 5.4052e-02],
#          [2.9983e-01, 2.9432e-01, 4.0585e-01],
#          [7.0548e-01, 4.5816e-02, 2.4871e-01],
#          [1.2445e-04, 6.6257e-04, 9.9921e-01],
#          [9.0791e-01, 9.1268e-02, 8.2249e-04],
#          [4.7002e-02, 8.8335e-01, 6.9650e-02],
#          [2.9096e-02, 2.1524e-02, 9.4938e-01],
#          [2.2912e-02, 9.2884e-01, 4.8246e-02],
#          [8.8577e-03, 9.7833e-01, 1.2808e-02],
#          [4.6624e-01, 4.3885e-01, 9.4911e-02],
#          [3.3276e-05, 8.3424e-04, 9.9913e-01],
#          [1.6619e-03, 4.9870e-03, 9.9335e-01],
#          [5.6350e-04, 6.2533e-03, 9.9318e-01],
# ...

# %%
preds, y = learn.get_preds()

# %%
y
# Out:
# tensor([2, 0, 0, 2, 0, 0, 2, 1, 1, 0, 2, 0, 1, 2, 1, 1, 1, 2, 2, 2, 1, 1, 1, 0,
#         1, 1, 2, 0, 2, 0, 0, 2, 0, 1, 1, 1, 0, 2, 2, 0, 2, 0, 1, 2, 0, 1, 1, 1,
#         1, 0, 2, 2, 0, 0, 0, 2, 1, 2, 1, 2, 2, 1, 0, 0, 1, 0, 0, 2, 2, 0, 0, 2,
#         2, 1, 1, 1, 1, 1, 0, 2, 2, 2, 0, 2, 1, 1, 2, 2, 2, 2, 2, 1, 0, 1, 0, 0,
#         2, 2, 1, 0])

# %%
preds.shape
# Out:
# torch.Size([100, 3])

# %%
df
# Out:
#       y         x1         x2        x3        x4        x5        x6  \
# 0     1  22.986015  27.383436  6.407323  4.296901  4.490673  3.424660
# 1     2  29.577003  20.469078  7.381665  5.359012  3.874273  4.016012
# 2     1  35.080229  29.498743  5.486379  4.367263  4.600076  3.466944
# 3     2  28.471735  24.297268  5.692822  4.256181  3.132808  4.633252
# 4     1  28.397544  24.629952  6.950566  5.095392  3.750686  4.619159
# 5     2  28.121538  24.367306  5.985106  4.756465  4.099127  4.500714
# 6     0  33.534136  19.444611  5.439420  4.230111  4.571987  5.298884
# 7     0  23.835976  25.228740  5.798278  4.666332  3.631912  3.491773
# 8     1  25.461478  17.913988  4.179152  4.201115  3.891272  4.331593
# 9     1  15.691679  29.385250  6.131513  3.119224  4.259205  4.172629
# 10    0  25.737081  30.651952  5.618914  4.264841  4.769643  4.918999
# 11    0  25.266138  30.388372  5.513634  4.498960  2.127926  5.201438
# ...

# %%
preds = np.zeros(3000)

# %%
np.argmax(np.array(learn.predict(test.iloc[0])[2]))
# Out:
# 1

# %%
for i in range(3000):
    preds[i] = np.argmax(np.array(learn.predict(test.iloc[i])[2]))

# %%
preds
# Out:
# array([1., 2., 2., 2., ..., 1., 1., 1., 1.])

# %%
results = pd.DataFrame(preds, columns = ['y'])

# %%
results
# Out:
#         y
# 0     1.0
# 1     2.0
# 2     2.0
# 3     2.0
# 4     2.0
# 5     0.0
# 6     1.0
# 7     1.0
# 8     2.0
# 9     2.0
# 10    2.0
# 11    2.0
# 12    1.0
# 13    2.0
# 14    0.0
# 15    0.0
# 16    2.0
# 17    0.0
# 18    2.0
# 19    1.0
# 20    2.0
# 21    1.0
# 22    2.0
# 23    0.0
# 24    1.0
# 25    2.0
# 26    1.0
# 27    2.0
# 28    0.0
# 29    2.0
# ...   ...
# 2970  2.0
# 2971  0.0
# 2972  0.0
# 2973  1.0
# 2974  2.0
# 2975  0.0
# 2976  0.0
# 2977  1.0
# 2978  0.0
# 2979  2.0
# 2980  1.0
# 2981  1.0
# 2982  2.0
# 2983  2.0
# 2984  2.0
# 2985  2.0
# 2986  2.0
# 2987  0.0
# 2988  2.0
# 2989  1.0
# 2990  0.0
# 2991  2.0
# 2992  0.0
# 2993  2.0
# 2994  2.0
# 2995  1.0
# 2996  1.0
# 2997  1.0
# 2998  1.0
# 2999  1.0
#
# [3000 rows x 1 columns]

# %%
ids = np.array(range(2000, 5000))

# %%
results = pd.DataFrame(ids)

# %%
results['y'] = preds

# %%
results.columns = ['Id', 'y']

# %%
results
# Out:
#         Id    y
# 0     2000  1.0
# 1     2001  2.0
# 2     2002  2.0
# 3     2003  2.0
# 4     2004  2.0
# 5     2005  0.0
# 6     2006  1.0
# 7     2007  1.0
# 8     2008  2.0
# 9     2009  2.0
# 10    2010  2.0
# 11    2011  2.0
# 12    2012  1.0
# 13    2013  2.0
# 14    2014  0.0
# 15    2015  0.0
# 16    2016  2.0
# 17    2017  0.0
# 18    2018  2.0
# 19    2019  1.0
# 20    2020  2.0
# 21    2021  1.0
# 22    2022  2.0
# 23    2023  0.0
# 24    2024  1.0
# 25    2025  2.0
# 26    2026  1.0
# 27    2027  2.0
# 28    2028  0.0
# 29    2029  2.0
# ...    ...  ...
# 2970  4970  2.0
# 2971  4971  0.0
# 2972  4972  0.0
# 2973  4973  1.0
# 2974  4974  2.0
# 2975  4975  0.0
# 2976  4976  0.0
# 2977  4977  1.0
# 2978  4978  0.0
# 2979  4979  2.0
# 2980  4980  1.0
# 2981  4981  1.0
# 2982  4982  2.0
# 2983  4983  2.0
# 2984  4984  2.0
# 2985  4985  2.0
# 2986  4986  2.0
# 2987  4987  0.0
# 2988  4988  2.0
# 2989  4989  1.0
# 2990  4990  0.0
# 2991  4991  2.0
# 2992  4992  0.0
# ...

# %%
results.to_csv('../seedlings/data/myFiles2/intromlresult1.csv', index=False)
